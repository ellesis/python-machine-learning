# %%
import sys
import pandas as pd
import traceback #excepiton
import glob #Reading the file
import json

# %%
def find_json_files(symbol):
    try:
        return glob.glob("articles/*.json")
    except Exception as ex:
        print(ex)
        tractback.print_exc(file=sys.stdout)

# %%
# find_json_files("AMZN")

# %%
def convert(file):
    with open(file) as f:
        ad = json.load(f)
    #print(ad)

    row = [{
        'date': ad['publish_date'],
        'symbol': ad['symbol'],
        'url': ad['link'],
        'raw': ad['text']
    }]
    
    return row

# %%
# convert("articles/NFLX-2020-05-08T12:15:08+00:00.json")

# %%
def make_articles_dataframe(symbol):
    df = pd.DataFrame(columns=['url', 'symbol', 'data', 'raw' ])
    
    files = find_json_files(symbol)
    for file in files:
        row = convert(file)
        df = df.append(row, ignore_index = True)
        
    return df

# %%
def main():
    df = make_articles_dataframe("AMZN")
    df.to_csv("AMZN_STEP1.csv", index=False)
    return df

main()
# Out:
#     data                              date  \
# 0    NaN         2020-05-05T20:58:01+00:00
# 1    NaN  2020-05-10T15:15:10.482000+00:00
# 2    NaN         2020-05-11T16:00:31+00:00
# 3    NaN         2020-05-09T00:05:59+00:00
# 4    NaN         2020-05-08T20:31:14+00:00
# ..   ...                               ...
# 219  NaN         2020-05-07T12:12:33+00:00
# 220  NaN         2020-05-05T16:29:43+00:00
# 221  NaN               2020-05-08T00:00:00
# 222  NaN         2020-05-11T14:27:35+00:00
# 223  NaN         2020-05-08T12:15:08+00:00
#
#                                                    raw symbol  \
# 0    Pinterest (PINS) reported first-quarter earnin...     FB
# 1    Apple Inc. (AAPL) beat quarterly earnings esti...   AAPL
# 2    Click here to read the full article.\n\nhas bu...     FB
# 3    (Bloomberg) -- Facebook Inc. users asked a jud...     FB
# 4    (For a live blog on the U.S. stock market, cli...   AAPL
# ..                                                 ...    ...
# 219  The stock market has rallied in recent weeks w...     FB
# 220  Marathon Capital Management founder Mario Cibe...     FB
# 221  Slack Technologies (NYSE:WORK) has been a divi...   AMZN
# 222  Over the past few months, some of the world’s ...   AMZN
# 223  As the coronavirus stock market tries to rebou...   NFLX
#
#                                                    url
# 0    https://www.investors.com/news/technology/pint...
# 1    https://www.investopedia.com/apple-beats-estim...
# 2    https://finance.yahoo.com/news/virtual-graduat...
# 3    https://finance.yahoo.com/news/facebook-users-...
# 4    https://finance.yahoo.com/news/us-stocks-wall-...
# ..                                                 ...
# 219  https://finance.yahoo.com/news/the-market-does...
# 220  https://finance.yahoo.com/news/mario-cibelli-b...
# 221  https://www.fool.com/investing/2020/05/08/wher...
# 222  https://finance.yahoo.com/news/why-amazon-face...
# 223  https://www.investors.com/etfs-and-funds/mutua...
#
# [224 rows x 5 columns]
